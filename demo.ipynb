# %%
from dataclasses import dataclass, field
from typing import List, Dict, Optional
import math
import json
from datetime import datetime
import matplotlib.pyplot as plt
import json


import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
@dataclass #one receipt line
class Item:
    item_name: str
    item_price: float
    payer: str
    owed_by: List[str]
    quantity: int=1
    # weighted split support
    weights: Dict[str, float] = field(default_factory=dict)  # e.g. {"Megan": 1, "Andrew": 2}
    use_weighted_split: bool = False  
    item_id: Optional[str] = None
    
@dataclass #the whole receipt
class Bill:
    members: List[str]
    items: List[Item]
    tax:float = 0.0
    tip:float = 0.0
    fees:float = 0.0
    extras_split_mode: str = 'equal'
    payer_paid_everything: bool = True
    payer: Optional[str] = None
    bill_name: Optional[str] = None
    receipt_total: Optional[float] = None

# %%
bill = Bill(members=[], items=[], bill_name=None, payer=None)

# %%
def add_member(bill, name):
    clean = name.strip().title()
    if not clean:
        return False
    if clean in bill.members:
        return False
    bill.members.append(clean)
    return True

def remove_member(bill, name):
    if name not in bill.members:
        return False, []
    bill.members.remove(name)
    
    invalid = []
    for it in bill.items:
        it.owed_by = [m for m in it.owed_by if m!= name]
        
        if len(it.owed_by) == 0:
            invalid.append(it) #case when nobody owes this item after removing name
            
    if bill.payer == name:
        bill.payer= None
    return True, invalid

def add_item(bill, item_name, item_price, owed_by):
    if not bill.members:
        return False, None
    
    clean_item_name = item_name.strip()
    if not clean_item_name:
        return False, None
    
    try:
        price = float(item_price)
    except (TypeError, ValueError):
        return False, None
    if price <= 0:
        return False, None
    
    owed_list = list(owed_by)

    if not owed_list:
        owed_list = bill.members.copy()
    else:    
        for name in owed_list:
            if name not in bill.members:
                return False, None
    
    payer_for_item = bill.payer if (bill.payer_paid_everything and bill.payer is not None) else ""

    new_item = Item(
        item_name=clean_item_name,
        item_price=price,
        payer=payer_for_item,
        owed_by=owed_list
    )

    bill.items.append(new_item)
    
    return True, new_item

def remove_item(bill, index):
    if index < 0 or index >= len(bill.items):
        return False
    bill.items.pop(index)
    return True


def set_payer(bill, payer_name):
    if payer_name not in bill.members:
        return False
    bill.payer = payer_name
    return True

# %%
# save/ load helpers
def bill_to_dict(bill):
    return {
        "bill_name": bill.bill_name,
        "members": list(bill.members),
        "payer_paid_everything": bool(bill.payer_paid_everything),
        "payer": bill.payer,
        "tax": float(bill.tax),
        "tip": float(bill.tip),
        "fees": float(bill.fees),
        "extras_split_mode": bill.extras_split_mode,
        "receipt_total": getattr(bill, "receipt_total", None),  # NEW

        "items": [
            {
                "item_name": it.item_name,
                "item_price": float(it.item_price),
                "payer": it.payer,
                "owed_by": list(it.owed_by),
                "quantity": int(getattr(it, "quantity", 1)),
                "item_id": getattr(it, "item_id", None),

                # NEW weighted fields
                "weights": dict(getattr(it, "weights", {})),
                "use_weighted_split": bool(getattr(it, "use_weighted_split", False)),
            }
            for it in bill.items
        ],
    }

def dict_to_bill(data):
    b = Bill(
        members=list(data.get("members", [])),
        items=[],
        tax=float(data.get("tax", 0.0)),
        tip=float(data.get("tip", 0.0)),
        fees=float(data.get("fees", 0.0)),
        extras_split_mode=data.get("extras_split_mode", "equal"),
        payer_paid_everything=bool(data.get("payer_paid_everything", True)),
        payer=data.get("payer", None),
        bill_name=data.get("bill_name", None),
        receipt_total=data.get("receipt_total", None),  # NEW
    )

    for it in data.get("items", []):
        item = Item(
            item_name=it.get("item_name", ""),
            item_price=float(it.get("item_price", 0.0)),
            payer=it.get("payer", b.payer if b.payer_paid_everything else ""),
            owed_by=list(it.get("owed_by", [])),
            quantity=int(it.get("quantity", 1)),
            item_id=it.get("item_id", None),
        )

        # Restore weighted fields (NEW)
        item.weights = dict(it.get("weights", {}))
        item.use_weighted_split = bool(it.get("use_weighted_split", False))

        b.items.append(item)

    return b

def save_bill(bill, path="bill_state.json"):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(bill_to_dict(bill), f, indent=2)
    return path

def load_bill(path="bill_state.json"):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return dict_to_bill(data)

def parse_money_text(s):
    try:
        return float(str(s).strip())
    except:
        return 0.0
    
def mark_dirty():
    save_reminder.value = "<span style='color:#b00020'><b>Reminder:</b> Save changes.</span>"

# %%
#Widget declarations 

out = widgets.Output()
members_list_box = widgets.VBox([])
items_list_box = widgets.VBox([])

# Pie / weights UI
pie_out = widgets.Output()
weights_box = widgets.VBox([])
item_to_edit = widgets.Dropdown(
    options=[("(select)", -1)],
    value=-1,
    description="Edit item",
    layout=widgets.Layout(width="320px")
)

# NEW: commit weighted split
save_weight_btn = widgets.Button(description="Save weighted split", button_style="success")
weight_status = widgets.Label("")

# --- PAYER UI ---
payer_paid_toggle = widgets.ToggleButtons(
    options=[("Yes", True), ("No", False)],
    value=bill.payer_paid_everything,
    description="Payer paid all?"
)

payer_dropdown = widgets.Dropdown(
    options=["(select)"],
    value="(select)",
    description="Payer",
    layout=widgets.Layout(width="320px")
)

# --- ITEMS UI ---
item_name_input = widgets.Text(
    description="Item",
    placeholder="e.g., Milk",
    layout=widgets.Layout(width="320px")
)

item_price_input = widgets.Text(
    description="Unit $",
    value="",
    placeholder="e.g., 3.99",
    layout=widgets.Layout(width="320px")
)

item_qty_input = widgets.BoundedIntText(
    description="Qty",
    value=1,
    min=1,
    max=999,
    layout=widgets.Layout(width="320px")
)

owed_by_select = widgets.SelectMultiple(
    options=[],
    description="Owed by",
    layout=widgets.Layout(width="320px", height="110px")
)

add_item_btn = widgets.Button(description="Add item", button_style="info")

# --- MEMBERS UI ---
member_input = widgets.Text(
    description="Name",
    placeholder="Add member name",
    layout=widgets.Layout(width="320px")
)

add_member_btn = widgets.Button(description="Add member", button_style="success")

# --- EXTRAS + SUMMARY UI ---
tax_input = widgets.FloatText(description="Tax", value=bill.tax, layout=widgets.Layout(width="320px"))
tip_input = widgets.FloatText(description="Tip", value=bill.tip, layout=widgets.Layout(width="320px"))
fees_input = widgets.FloatText(description="Fees", value=bill.fees, layout=widgets.Layout(width="320px"))

extras_mode = widgets.ToggleButtons(
    options=[("Equal", "equal"), ("Proportional", "proportional")],
    value=bill.extras_split_mode,
    description="Extras split"
)

calc_btn = widgets.Button(description="Calculate totals", button_style="primary")
summary_out = widgets.Output()


save_btn = widgets.Button(description="Save", button_style="success")
load_btn = widgets.Button(description="Load", button_style="warning")
save_status = widgets.Label("")

receipt_total_input = widgets.Text(
    description="Receipt total",
    value="",
    placeholder="e.g., 58.42",
    layout=widgets.Layout(width="320px")
)
total_check_out = widgets.Output()

computed_total_label = widgets.HTML("")

save_reminder = widgets.HTML("")
# Out:
# Totals check:
#   Computed total: $156.96
#   Receipt total:  $156.96
#   Difference:     $0.00

# %%
# compute functions 
def compute_owed_subtotals(bill):
    members = bill.members
    owed = {m: 0.0 for m in members}
          
    for it in bill.items:
    # If weighted mode is enabled and weights exist, split proportionally
        if getattr(it, "use_weighted_split", False) and getattr(it, "weights", None):
            names = list(it.weights.keys())
            vals = [max(0.0, float(it.weights.get(n, 0.0))) for n in names]
            total_w = sum(vals)

            if total_w > 0:
                for n, w in zip(names, vals):
                    if n in owed:
                        owed[n] += it.item_price * (w / total_w)
                continue  # done with this item

        # Otherwise, default to equal split among owed_by (or all members)
        group = it.owed_by if it.owed_by else members
        if not group:
            continue
        share = it.item_price / len(group)
        for m in group:
            if m in owed:
                owed[m] += share

    extras = float(bill.tax) + float(bill.tip) + float(bill.fees)
    if extras > 0 and members:
        if bill.extras_split_mode == "equal":
            per = extras / len(members)
            for m in members:
                owed[m] += per
        elif bill.extras_split_mode == "proportional":
            base = sum(owed.values())
            if base <= 1e-9:
                per = extras / len(members)
                for m in members:
                    owed[m] += per
            else:
                for m in members:
                    owed[m] += extras * (owed[m] / base)

    for m in owed:
        owed[m] = round(owed[m] + 1e-9, 2)

    return owed


def compute_payments_to_payer(bill):
    owed = compute_owed_subtotals(bill)
    payer = bill.payer
    if not payer:
        return owed, None, {}

    payments = {m: (0.0 if m == payer else owed[m]) for m in owed}
    return owed, payer, payments

 
def computed_bill_total(bill):
    items_total = sum(float(it.item_price) for it in bill.items)
    extras_total = float(bill.tax) + float(bill.tip) + float(bill.fees)
    return round(items_total + extras_total + 1e-9, 2)

# %%
# pie helpers
def ensure_item_weights(item, bill):
    """
    Ensure item has a .weights dict for the people who owe it.
    Default: 1.0 share per person.
    """
    if not hasattr(item, "weights") or item.weights is None:
        item.weights = {}

    group = list(item.owed_by) if item.owed_by else list(bill.members)

    # Keep only relevant people; add missing with default weight 1.0
    item.weights = {n: float(item.weights.get(n, 1.0)) for n in group}


def render_item_pie(item):
    """
    Draws a pie chart for one item using item.weights.
    Also prints a legend-style $ breakdown.
    """
    ensure_item_weights(item, bill)

    names = list(item.weights.keys())
    vals = [max(0.0, float(item.weights[n])) for n in names]
    total_w = sum(vals)

    with pie_out:
        clear_output(wait=True)

        if not names:
            print("Select 'Owed by' for this item to show a pie.")
            return

        if total_w <= 0:
            print("Set at least one weight > 0.")
            return

        pct = [v / total_w for v in vals]

        plt.figure(figsize=(4.2, 4.2))
        plt.pie(
            pct,
            labels=[f"{n}\n{round(p*100)}%" for n, p in zip(names, pct)],
            startangle=90
        )
        plt.title(f"{item.item_name} — ${item.item_price:.2f}")
        plt.show()

        # Breakdown with dollars
        print("Split mode: Weighted (by shares)")
        print("Breakdown:")
        for n, p in zip(names, pct):
            print(f"  {n}: {p*100:.1f}%  →  ${item.item_price*p:.2f}")
        print("\nTip: adjust shares below (drag-to-adjust pie is a future feature).")


def build_weight_controls(item):
    """
    Creates a numeric stepper per person (shares).
    Changing a value updates the pie immediately.
    """
    ensure_item_weights(item, bill)

    rows = []
    for name in item.weights.keys():
        w = widgets.BoundedFloatText(
            value=float(item.weights[name]),
            min=0,
            max=999,
            step=1,
            description=name,
            layout=widgets.Layout(width="320px")
        )

        def _on_change(change, n=name):
            item.weights[n] = float(change["new"])
            mark_dirty()
            render_item_pie(item)

        w.observe(_on_change, names="value")
        rows.append(w)

    weights_box.children = rows


def on_item_to_edit(change):
    idx = change["new"]
    if idx == -1:
        weights_box.children = []
        with pie_out:
            clear_output()
        return

    item = bill.items[idx]
    build_weight_controls(item)
    render_item_pie(item)


item_to_edit.observe(on_item_to_edit, names="value")

# %%
#  UI actions (event handlers)

def _remove_member(name):
    if "remove_member" in globals():
        success, invalid_items = remove_member(bill, name)
        if invalid_items:
            with out:
                print("\nNOTE: These items now have owed_by=[] and need fixing:")
                for it in invalid_items:
                    print("-", it.item_name)
    else:
        if name in bill.members:
            bill.members.remove(name)
            for it in bill.items:
                it.owed_by = [m for m in it.owed_by if m != name]
            if bill.payer == name:
                bill.payer = None
    refresh()


def _remove_item(index):
    if "remove_item" in globals():
        remove_item(bill, index)
    else:
        if 0 <= index < len(bill.items):
            bill.items.pop(index)
    refresh()


def on_add_member(_):
    ok = add_member(bill, member_input.value)
    if ok:
        member_input.value = ""
        save_reminder.value = "<span style='color:#b00020'><b>Reminder:</b> Save your progress.</span>"
    refresh()


def on_toggle_payer_paid(change):
    bill.payer_paid_everything = bool(change["new"])
    refresh()


def on_payer_change(change):
    val = change["new"]
    if val == "(select)":
        bill.payer = None
        refresh()
        return
    set_payer(bill, val)
    refresh()


def on_add_item(_):
    qty = int(item_qty_input.value or 1)
    try:
        unit_price = float(item_price_input.value.strip())
    except:
        unit_price = 0.0
    line_total = unit_price * qty
    clean_name = item_name_input.value.strip()
    clean_name = " ".join(w.capitalize() for w in clean_name.split())

    ok, new_item = add_item(
        bill,
        clean_name,
        line_total,
        list(owed_by_select.value)
    )

    if ok:
        new_item.quantity = qty

        # Initialize weights for the people who owe it (default 1 share each)
        group = list(new_item.owed_by) if new_item.owed_by else list(bill.members)
        new_item.weights = {n: 1.0 for n in group}

        item_name_input.value = ""
        item_price_input.value = ""
        item_qty_input.value = 1
        save_reminder.value = "<span style='color:#b00020'><b>Reminder:</b> Save your progress.</span>"
        

    refresh()
    
def on_save_weighted_split(_):
    idx = item_to_edit.value
    if idx == -1:
        weight_status.value = "Select an item first."
        return

    it = bill.items[idx]
    if not getattr(it, "weights", None):
        weight_status.value = "No weights to save."
        return

    # Validate at least one positive weight
    total_w = sum(max(0.0, float(v)) for v in it.weights.values())
    if total_w <= 0:
        weight_status.value = "Set at least one weight above 0."
        return

    # Commit weighted split
    it.use_weighted_split = True
    mark_dirty()

    # Optional, keep owed_by in sync with the weighted people
    it.owed_by = list(it.weights.keys())

    weight_status.value = "Saved. Weighted split will be used in Calculate."
    refresh()

save_weight_btn.on_click(on_save_weighted_split)



def on_calculate(_):
    bill.tax = float(tax_input.value or 0.0)
    bill.tip = float(tip_input.value or 0.0)
    bill.fees = float(fees_input.value or 0.0)
    bill.extras_split_mode = extras_mode.value
    bill.receipt_total = parse_money_text(receipt_total_input.value) or None


    with summary_out:
        clear_output()

        if not bill.members:
            print("Add members first.")
            return
        if not bill.items:
            print("Add at least one item.")
            return
        if bill.payer_paid_everything and not bill.payer:
            print("Select a payer first.")
            return
        if not bill.payer_paid_everything:
            print("Multi payer mode not implemented yet. Switch 'Payer paid all?' to Yes.")
            return

        owed, payer, payments = compute_payments_to_payer(bill)

        print("Owed totals (each person’s share):")
        for m in bill.members:
            print(f"  {m}: ${owed[m]:.2f}")

        if payer:
            print("\nPay the payer:")
            for m in bill.members:
                if m != payer:
                    print(f"  {m} -> {payer}: ${payments[m]:.2f}")
                    
    total = computed_bill_total(bill)
    entered = parse_money_text(receipt_total_input.value)
    if entered > 0 and abs(total - entered) >= 0.01:
        print("\n⚠️ Receipt total does not match computed total.")
        print("Did you enter everything (all items, tax/tip/fees, quantities)?")

    diff = round(total - entered, 2)

    print("\nTotals check:")
    print(f"  Computed total: ${total:.2f}")
    if entered > 0:
        print(f"  Receipt total:  ${entered:.2f}")
        print(f"  Difference:     ${diff:.2f}")
    else:
        print("  Receipt total not entered.")
        
        
def computed_bill_total(bill):
    items_total = sum(float(it.item_price) for it in bill.items)
    extras_total = float(bill.tax) + float(bill.tip) + float(bill.fees)
    return round(items_total + extras_total + 1e-9, 2)




def on_save(_):
    # sync from UI -> bill before saving
    entered = parse_money_text(receipt_total_input.value)
    bill.receipt_total = None if entered <= 0 else round(entered, 2)
    
    path = save_bill(bill, "my_demo_bill.json")
    save_status.value = f"Saved to {path}"
    save_reminder.value = "<span style='color:#2e7d32'><b>Saved.</b></span>"


def on_load(_):
    global bill
    bill = load_bill("my_demo_bill.json")
    # sync from bill -> UI
    if bill.receipt_total is None:
        receipt_total_input.value = ""
    else:
        receipt_total_input.value = f"{bill.receipt_total:.2f}"
    save_status.value = "Loaded saved bill"
    refresh()

save_btn.on_click(on_save)
load_btn.on_click(on_load)


def format_weight_tag(it):
    if not getattr(it, "use_weighted_split", False):
        return ""
    w = getattr(it, "weights", None)
    if not w:
        return " (weighted)"

    names = list(w.keys())
    vals = [max(0.0, float(w.get(n, 0.0))) for n in names]
    total = sum(vals)
    if total <= 0:
        return " (weighted)"

    # show integer-ish shares (e.g., 4:3:4). If you use steppers, these are already integers.
    shares = [int(round(v)) for v in vals]
    # if rounding collapses to zeros, fall back to percents
    if sum(shares) <= 0:
        perc = [round(100 * v / total) for v in vals]
        return " (weighted " + "/".join(f"{p}%" for p in perc) + ")"

    return " (weighted " + ":".join(str(s) for s in shares) + ")"


def on_receipt_total_change(change):
    mark_dirty()

def on_extras_change(change):
    mark_dirty()

# %%
# REFRESH

def refresh():
    # Members list
    member_rows = []
    for m in bill.members:
        rm_btn = widgets.Button(description="Remove", layout=widgets.Layout(width="90px"))
        rm_btn.on_click(lambda _b, name=m: _remove_member(name))
        member_rows.append(widgets.HBox([widgets.Label(m, layout=widgets.Layout(width="180px")), rm_btn]))
    members_list_box.children = member_rows

    # Payer toggle/dropdown
    bill.payer_paid_everything = bool(payer_paid_toggle.value)

    payer_dropdown.options = ["(select)"] + bill.members
    if bill.payer in bill.members:
        payer_dropdown.value = bill.payer
    else:
        payer_dropdown.value = "(select)"
        bill.payer = None

    payer_dropdown.disabled = (bill.payer_paid_everything is False)

    # Owed-by options
    owed_by_select.options = bill.members

    # Items list + edit dropdown options
    item_rows = []
    for i, it in enumerate(bill.items):
        qty = getattr(it, "quantity", 1) or 1
        unit = it.item_price / qty
        tag = format_weight_tag(it)
        label = f"[{i}] {it.item_name}{tag} x{qty} | unit ${unit:.2f} | line ${it.item_price:.2f} | owed_by={it.owed_by}"
        rm = widgets.Button(description="Remove", icon="trash", layout=widgets.Layout(width="90px"))
        rm.on_click(lambda _b, idx=i: _remove_item(idx))
        item_rows.append(widgets.HBox([widgets.Label(label, layout=widgets.Layout(width="520px")), rm]))
    items_list_box.children = item_rows

    item_to_edit.options = [("(select)", -1)] + [(f"{i}: {it.item_name}", i) for i, it in enumerate(bill.items)]
    if item_to_edit.value not in [opt[1] for opt in item_to_edit.options]:
        item_to_edit.value = -1
        
    entered = float(receipt_total_input.value or 0.0)
    total = computed_bill_total(bill)
    if entered > 0 and abs(total - entered) >= 0.01:
        diff = total - entered
        computed_total_label.value = (
            f"<b>Computed total:</b> ${total:.2f} "
            f"<span style='color:#b00020'>(mismatch vs receipt: {diff:+.2f})</span>"
        )
    else:
        computed_total_label.value = f"<b>Computed total:</b> ${total:.2f}"

    if getattr(bill, "receipt_total", None) is None:
        receipt_total_input.value = ""
    else:
        receipt_total_input.value = f"{bill.receipt_total:.2f}"


    # Debug
    with out:
        clear_output()
        print("Current Bill State")
        print("members:", bill.members)
        print("payer_paid_everything:", bill.payer_paid_everything)
        print("payer:", bill.payer)
        print("items:", [(it.item_name, it.item_price, getattr(it, "quantity", 1), it.owed_by) for it in bill.items])
        print("tax/tip/fees:", bill.tax, bill.tip, bill.fees, "| extras_split_mode:", bill.extras_split_mode)

# %%
# layout + display
add_member_btn.on_click(on_add_member)
payer_paid_toggle.observe(on_toggle_payer_paid, names="value")
payer_dropdown.observe(on_payer_change, names="value")
add_item_btn.on_click(on_add_item)
calc_btn.on_click(on_calculate)


# NEW: mark dirty on edits
receipt_total_input.observe(on_receipt_total_change, names="value")
tax_input.observe(on_extras_change, names="value")
tip_input.observe(on_extras_change, names="value")
fees_input.observe(on_extras_change, names="value")
extras_mode.observe(on_extras_change, names="value")

ui = widgets.VBox([
    widgets.HBox([save_btn, load_btn, save_status]),
    save_reminder,
    widgets.HTML("<h3>1) Members</h3>"),
    widgets.HBox([member_input, add_member_btn]),
    members_list_box,

    widgets.HTML("<h3>2) Who paid?</h3>"),
    payer_paid_toggle,
    payer_dropdown,

    widgets.HTML("<h3>3) Items</h3>"),
    item_name_input,
    item_price_input,
    item_qty_input,
    owed_by_select,
    add_item_btn,
    items_list_box,

    widgets.HTML("<h3>3.5) Weighted split preview</h3>"),
    item_to_edit,
    weights_box,
    widgets.HBox([save_weight_btn, weight_status]),
    pie_out,


    widgets.HTML("<h3>4) Extras + Summary</h3>"),
    tax_input,
    tip_input,
    fees_input,
    extras_mode,
    receipt_total_input,
    calc_btn,
    computed_total_label,
    summary_out,

    widgets.HTML("<hr>"),
    out
])

display(ui)
refresh()
